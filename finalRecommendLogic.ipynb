# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors

# Load clustered dataset
df_clustered = pd.read_csv("Clustered_Exhibition_Data.csv")

# Features to encode
features = ['Nationality', 'Gender', 'ExhibitionRole']

# Encode categorical features
label_encoders = {}
for col in features:
    le = LabelEncoder()
    df_clustered[col] = le.fit_transform(df_clustered[col])
    label_encoders[col] = le

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_clustered[features])

# Apply K-Means clustering
k = 6
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
df_clustered["Cluster"] = kmeans.fit_predict(X_scaled)

# Train KNN within each cluster
knn_models = {}
for cluster_id in range(k):
    cluster_data = df_clustered[df_clustered["Cluster"] == cluster_id][features]
    if not cluster_data.empty:
        knn = NearestNeighbors(n_neighbors=5, metric="euclidean")
        knn.fit(cluster_data)
        knn_models[cluster_id] = knn

# Recommendation function
def recommend_exhibitions(user_input):
    user_data = pd.DataFrame([user_input], columns=features)

    # Encode user input
    for col in features:
        if user_data[col][0] not in label_encoders[col].classes_:
            user_data[col] = label_encoders[col].classes_[0]
        user_data[col] = label_encoders[col].transform(user_data[col])

    # Scale user input
    user_scaled = scaler.transform(user_data)

    # Convert back to DataFrame (fixes NearestNeighbors warning)
    user_scaled_df = pd.DataFrame(user_scaled, columns=features)

    # Assign user to a cluster
    user_cluster = kmeans.predict(user_scaled)[0]

    if user_cluster in knn_models:
        knn = knn_models[user_cluster]
        distances, indices = knn.kneighbors(user_scaled_df)

        recommended_exhibitions = df_clustered.iloc[indices[0]].copy()

        # Convert encoded values back to original categories
        for col in features:
            recommended_exhibitions[col] = label_encoders[col].inverse_transform(recommended_exhibitions[col])

        # Prioritize exact role matches
        exact_match = recommended_exhibitions[recommended_exhibitions["ExhibitionRole"] == user_input[2]]

        return exact_match if not exact_match.empty else recommended_exhibitions

    else:
        return "No recommendations found."

# Test users
test_users = [
    ["American", "Female", "Curator"],
    ["European", "Female", "Artist"],
    ["Asian", "Male", "Painter"]
]

# Get recommendations
for test_user in test_users:
    print(f"\nRecommended Exhibitions for User {test_user}:")
    print(recommend_exhibitions(test_user))
# Out:
# Recommended Exhibitions for User ['American', 'Female', 'Curator']:
#      ExhibitionID ExhibitionNumber  \
# 232        2606.0               12
# 100        2944.0               5a
# 182        2729.0                9
# 185        2729.0                9
# 168        2729.0                9
#
#                                        ExhibitionTitle ExhibitionBeginDate  \
# 232  Memorial Exhibition: The Collection of the Lat...          1931-05-17
# 100    46 Painters and Sculptors under 35 Years of Age          1930-11-04
# 182         Painting and Sculpture by Living Americans          1930-03-12
# 185         Painting and Sculpture by Living Americans          1930-03-12
# 168         Painting and Sculpture by Living Americans          1930-03-12
#
#     ExhibitionEndDate                       ExhibitionURL ExhibitionRole  \
# 232        1931-06-10  moma.org/calendar/exhibitions/1707         Artist
# 100        1930-04-27  moma.org/calendar/exhibitions/2025         Artist
# 182        1931-01-20  moma.org/calendar/exhibitions/1916         Artist
# 185        1931-01-20  moma.org/calendar/exhibitions/1916         Artist
# 168        1931-01-20  moma.org/calendar/exhibitions/1916         Artist
#
#     ConstituentType      DisplayName        AlphaSort  ...  LastName Suffix  \
# 232      Individual     André Derain     Derain André  ...    Derain    NaN
# 100      Individual       Ann Weaver       Weaver Ann  ...    Weaver    NaN
# 182      Individual      Karl Knaths      Knaths Karl  ...    Knaths    NaN
# 185      Individual  Gaston Lachaise  Lachaise Gaston  ...  Lachaise    NaN
# 168      Individual   Andrew Dasburg   Dasburg Andrew  ...   Dasburg    NaN
#
#     Institution Nationality ConstituentBeginDate ConstituentEndDate  \
# 232         NaN      French               1880.0             1954.0
# 100         NaN     Unknown                  NaN                NaN
# 182         NaN    American               1891.0             1971.0
# 185         NaN    American               1882.0             1935.0
# 168         NaN    American               1887.0             1979.0
#
#                             ArtistBio   Gender          ConstituentURL Cluster
# 232                 French, 1880–1954     Male   moma.org/artists/1500       0
# 100                               NaN  Unknown  moma.org/artists/49759       3
# 182               American, 1891–1971     Male   moma.org/artists/3159       4
# 185  American, born France. 1882–1935     Male   moma.org/artists/3332       4
# 168               American, 1887–1979     Male  moma.org/artists/61688       4
#
# [5 rows x 22 columns]
#
# Recommended Exhibitions for User ['European', 'Female', 'Artist']:
#     ExhibitionID ExhibitionNumber                     ExhibitionTitle  \
# 44        2942.0                3                   Painting in Paris
# 3         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 50        2636.0                4     Weber, Klee, Lehmbruck, Maillol
# 2         2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
#
#    ExhibitionBeginDate ExhibitionEndDate                       ExhibitionURL  \
# 44          1930-01-19        1930-02-03  moma.org/calendar/exhibitions/2024
# 3           1929-07-11        1929-07-12  moma.org/calendar/exhibitions/1767
# 50          1930-12-03        1930-02-04  moma.org/calendar/exhibitions/1766
# 2           1929-07-11        1929-07-12  moma.org/calendar/exhibitions/1767
#
#    ExhibitionRole ConstituentType                DisplayName  \
# 44         Artist      Individual  André Dunoyer de Segonzac
# 3          Artist      Individual           Vincent van Gogh
# 50         Artist      Individual                  Paul Klee
# 2          Artist      Individual               Paul Gauguin
#
#                     AlphaSort  ...  LastName Suffix Institution Nationality  \
# 44  Segonzac André Dunoyer de  ...  Segonzac    NaN         NaN      French
# 3            Gogh Vincent van  ...  van Gogh    NaN         NaN       Dutch
# 50                  Klee Paul  ...      Klee    NaN         NaN      German
# 2                Gauguin Paul  ...   Gauguin    NaN         NaN      French
#
#    ConstituentBeginDate ConstituentEndDate  \
# 44               1884.0             1974.0
# 3                1853.0             1890.0
# 50               1879.0             1940.0
# 2                1848.0             1903.0
#
#                               ArtistBio  Gender         ConstituentURL Cluster
# 44                    French, 1884–1974    Male  moma.org/artists/5318       0
# 3                      Dutch, 1853–1890    Male  moma.org/artists/2206       0
# 50  German, born Switzerland. 1879–1940    Male  moma.org/artists/3130       0
# 2                     French, 1848–1903    Male  moma.org/artists/2098       0
#
# [4 rows x 22 columns]
#
# Recommended Exhibitions for User ['Asian', 'Male', 'Painter']:
#       ExhibitionID ExhibitionNumber  \
# 255         2854.0               14
# 1613         246.0               46
# 1875        3030.0               52
# 294         2981.0               15
# 1874        3030.0               52
#
#                                     ExhibitionTitle ExhibitionBeginDate  \
# 255                                    Diego Rivera          1931-12-22
# 1613                        Cubism and Abstract Art          1936-02-03
# 1875                   New Horizons in American Art          1936-09-14
# 294   Modern Architecture: International Exhibition          1932-09-02
# 1874                   New Horizons in American Art          1936-09-14
#
#      ExhibitionEndDate                       ExhibitionURL ExhibitionRole  \
# 255         1932-01-27  moma.org/calendar/exhibitions/1979         Artist
# 1613        1936-04-19  moma.org/calendar/exhibitions/2748         Artist
# 1875        1936-12-10  moma.org/calendar/exhibitions/2942         Artist
# 294         1932-03-23  moma.org/calendar/exhibitions/2044         Artist
# 1874        1936-12-10  moma.org/calendar/exhibitions/2942         Artist
#
#      ConstituentType      DisplayName        AlphaSort  ...  LastName Suffix  \
# 255       Individual     Diego Rivera     Rivera Diego  ...    Rivera    NaN
# 1613      Individual    Gino Severini    Severini Gino  ...  Severini    NaN
# 1875      Individual      Carlus Dyer      Dyer Carlus  ...      Dyer    NaN
# 294       Individual  William Lescaze  Lescaze William  ...   Lescaze    NaN
# 1874      Individual     Mabel Dwight     Dwight Mabel  ...    Dwight    NaN
#
#      Institution Nationality ConstituentBeginDate ConstituentEndDate  \
# 255          NaN     Mexican               1886.0             1957.0
# 1613         NaN     Italian               1883.0             1966.0
# 1875         NaN    American                  NaN                NaN
# 294          NaN    American               1896.0             1969.0
# 1874         NaN    American               1876.0             1955.0
#
#                                   ArtistBio  Gender         ConstituentURL  \
# 255                      Mexican, 1886–1957    Male  moma.org/artists/4942
# 1613                     Italian, 1883–1966    Male  moma.org/artists/5360
# 1875                               American    Male  moma.org/artists/1667
# 294   American, born Switzerland. 1896–1969    Male  moma.org/artists/7425
# 1874                    American, 1876–1955  Female  moma.org/artists/1665
#
#      Cluster
# 255        0
# 1613       0
# 1875       4
# 294        4
# 1874       5
#
# [5 rows x 22 columns]
